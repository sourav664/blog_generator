# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'Latest news about AI'})
results
# Out:
# C:\Users\soura\AppData\Local\Temp\ipykernel_20444\1030070086.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'AI News | Latest News | Insights Powering AI-Driven Business Growth',
#   'url': 'https://www.artificialintelligence-news.com/',
# ...

# %%
from typing import List

def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized

# %%
c = _tavily_search('Latest news about AI')

# %%
gt
# Out:
# [{'title': 'Latest AI News and AI Breakthroughs that Matter Most: 2026 & 2025',
#   'url': 'https://www.crescendo.ai/news/latest-ai-news-and-updates',
# ...

# %%
from pathlib import Path
dir = Path.cwd().parent
# Out:
# WindowsPath('c:/Users/soura/OneDrive/Desktop/blog_generator')

# %%
image_path1 = dir / "generated_images" /prompt_text.replace(" ", "_") + ".png"

# %%
from openai import OpenAI
from pathlib import Path
dir = Path.cwd().parent


client = OpenAI()

prompt_text = "A futuristic AI agent working on multiple screens"

# Generate image
result = client.images.generate(
    model="gpt-image-1.5",
    prompt= prompt_text,
    size="1024x1024"
)

# Get base64 string
image_base64 = result.data[0].b64_json

image_part = getattr(result, "data", None)


# image_path = dir / "generated_images" /prompt_text.replace(" ", "_") + ".png"
# # Decode base64 → binary
# # image_bytes = base64.b64decode(image_base64)

# image_path.write_bytes(image_base64)

# %%
dirimage_part[0].b64_json
# Out:
# '...'

# %%
dir.
# Out:
# WindowsPath('c:/Users/soura/OneDrive/Desktop/blog_generator')

# %%
import base64
from pathlib import Path

root_path = Path.cwd().parent
destination_path = root_path / "generated_images"
destination_path.mkdir(parents=True, exist_ok=True)

image_saved = destination_path / (prompt_text.replace(" ", "_") + ".png")
image_bytes = base64.b64decode(image_base64)
image_saved.write_bytes(image_bytes)
# Out:
# 1919422

# %%
import base64
image_dir = Path("images")
image_dir.mkdir(parents=True, exist_ok=True)

image_saved = dir / image_dir / (prompt_text.replace(" ", "_") + ".png")
image_bytes = base64.b64decode(image_base64)
image_saved.write_bytes(image_bytes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 7
#       5 image_saved = dir / image_dir / (prompt_text.replace(" ", "_") + ".png")
#       6 image_bytes = base64.b64decode(image_base64)
# ----> 7 image_saved.write_bytes(image_bytes)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.7-windows-x86_64-none\Lib\pathlib\_abc.py:641, in PathBase.write_bytes(self, data)
#     639 # type-check for the buffer interface before truncating the file
#     640 view = memoryview(data)
# --> 641 with self.open(mode='wb') as f:
#     642     return f.write(view)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.7-windows-x86_64-none\Lib\pathlib\_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     535 if "b" not in mode:
#     536     encoding = io.text_encoding(encoding)
# ...

# %%
class Person:
    def __init__(self):
        self.name = "Sourav"

p = Person()

result = getattr(p, "name", "Not Found")
print(result)
# Out:
# Sourav
